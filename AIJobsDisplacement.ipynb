# %% [markdown]
# ### Main objectives for this project
# #### Look at sectors jobs as a whole via pie chart

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# functions 
def openCSV(fileName):
    df = pd.read_csv(fileName)
    return df

def dropNA(df):
    df = df.dropna()
    return df

def deleteEveryOtherRow(df):
    df = df.iloc[1::2]
    return df

def saveFile(df, fileName):
    df.to_csv(fileName, index=False)

def renameColumns(df, array):
    df.columns = [array]
    return df

# %%
SectorGDP = openCSV('./SectorGDP.csv')
SectorGDP
# Out:
#                                                  Name  \
# 0                              Gross domestic product
# 1                                  Private industries
# 2         Agriculture, forestry, fishing, and hunting
# 3                                              Mining
# 4                                           Utilities
# 5                                        Construction
# 6                                       Manufacturing
# 7                                       Durable goods
# 8                                    Nondurable goods
# 9                                     Wholesale trade
# 10                                       Retail trade
# 11                     Transportation and warehousing
# 12                                        Information
# 13  Finance, insurance, real estate, rental, and l...
# 14                              Finance and insurance
# 15                 Real estate and rental and leasing
# 16                 Professional and business services
# 17   Professional, scientific, and technical services
# 18            Management of companies and enterprises
# 19       Administrative and waste management services
# 20  Educational services, health care, and social ...
# 21                               Educational services
# 22                  Health care and social assistance
# 23  Arts, entertainment, recreation, accommodation...
# 24                Arts, entertainment, and recreation
# 25                    Accommodation and food services
# 26                  Other services, except government
# 27                                         Government
# 28                                            Federal
# 29                                    State and local
# 30                 Private goods-producing industries
# 31              Private services-producing industries
#
#     Q4 2021 (Billions of Dollars)
# 0                         24002.8
# 1                         21166.6
# 2                           255.0
# 3                           336.1
# 4                           401.6
# 5                           991.9
# 6                          2714.2
# 7                          1440.0
# 8                          1274.2
# 9                          1444.6
# 10                         1434.1
# 11                          698.0
# 12                         1360.6
# 13                         5024.7
# 14                         2003.6
# 15                         3021.1
# 16                         3109.1
# 17                         1863.4
# 18                          435.7
# 19                          810.0
# 20                         1994.2
# 21                          266.8
# 22                         1727.4
# 23                          934.7
# 24                          220.9
# 25                          713.9
# 26                          467.9
# 27                         2836.2
# 28                          897.8
# 29                         1938.4
# 30                         4297.1
# 31                        16869.5

# %% [markdown]
# #### Combine SectorGDP with SectorTotalJobs

# %%
SectorTotalJobs = openCSV('./SectorTotalJobs.csv')
SectorTotalJobs
# Out:
#                                 Industry Sector  Employment, 2010  \
# 0                                        Mining             654.8
# 1                                  Construction            5518.3
# 2                                 Manufacturing           11529.1
# 3                                     Utilities             552.8
# 4                               Wholesale trade            5386.6
# 5                                  Retail trade           14446.3
# 6                Transportation and warehousing            4179.2
# 7                                   Information            2707.2
# 8                          Financial activities            7694.8
# 9            Professional and business services           16782.9
# 10                         Educational services            3155.1
# 11            Health care and social assistance           16820.0
# 12                      Leisure and hospitality           13048.7
# 13                               Other services            5997.7
# 14                           Federal government            2977.0
# 15                   State and local government           19513.5
# 16  Agriculture, forestry, fishing, and hunting            2102.9
# 17                 Nonagriculture self-employed            8859.8
#
#     Employment, 2020  Employment, 2030  Employment change,   \
# 0              573.1             671.3                -81.7
# 1             7269.4            7584.4               1751.1
# 2            12179.1           12322.8                650.0
# 3              541.9             502.9                -10.9
# 4             5639.8            5780.8                253.2
# 5            14853.1           14266.3                406.8
# 6             5555.1            6189.2               1375.9
# 7             2694.4            2977.2                -12.8
# 8             8723.7            9027.1               1028.9
# 9            20245.7           22265.6               3462.8
# 10            3459.4            3983.6                304.3
# 11           19776.2           23092.6               2956.2
# 12           13326.7           16566.3                278.0
# 13            6048.8            6804.9                 51.1
# 14            2929.0            2860.9                -48.0
# 15           18979.8           19797.1               -533.7
# 16            2241.3            2296.3                138.4
# 17            8497.3            8424.3               -362.5
#
#     Employment change,  Percent distribution, 2010  \
# 0                 98.2                         0.5
# 1                315.0                         3.9
# 2                143.7                         8.1
# 3                -39.0                         0.4
# 4                141.0                         3.8
# 5               -586.8                        10.2
# 6                634.1                         2.9
# 7                282.8                         1.9
# 8                303.4                         5.4
# 9               2019.9                        11.8
# 10               524.2                         2.2
# 11              3316.4                        11.9
# 12              3239.6                         9.2
# 13               756.1                         4.2
# 14               -68.1                         2.1
# 15               817.3                        13.7
# 16                55.0                         1.5
# 17               -73.0                         6.2
#
#     Percent distribution, 2020  Percent distribution, 2030  \
# 0                          0.4                         0.4
# 1                          4.7                         4.6
# 2                          7.9                         7.4
# 3                          0.4                         0.3
# 4                          3.7                         3.5
# 5                          9.7                         8.6
# 6                          3.6                         3.7
# 7                          1.8                         1.8
# 8                          5.7                         5.5
# 9                         13.2                        13.5
# 10                         2.3                         2.4
# 11                        12.9                        14.0
# 12                         8.7                        10.0
# 13                         3.9                         4.1
# 14                         1.9                         1.7
# 15                        12.4                        12.0
# 16                         1.5                         1.4
# 17                         5.5                         5.1
#
#     Compound annual rate of change, 2010–20  \
# 0                                      -1.3
# 1                                       2.8
# 2                                       0.5
# 3                                      -0.2
# 4                                       0.5
# 5                                       0.3
# 6                                       2.9
# 7                                       0.0
# 8                                       1.3
# 9                                       1.9
# 10                                      0.9
# 11                                      1.6
# 12                                      0.2
# 13                                      0.1
# 14                                     -0.2
# 15                                     -0.3
# 16                                      0.6
# 17                                     -0.4
#
#     Compound annual rate of change, 2020–30
# 0                                       1.6
# 1                                       0.4
# 2                                       0.1
# 3                                      -0.7
# 4                                       0.2
# 5                                      -0.4
# 6                                       1.1
# 7                                       1.0
# 8                                       0.3
# 9                                       1.0
# 10                                      1.4
# 11                                      1.6
# 12                                      2.2
# 13                                      1.2
# 14                                     -0.2
# 15                                      0.4
# 16                                      0.2
# 17                                     -0.1

# %% [markdown]
# Turn Columns into list

# %%
SectorTotalJobsList = SectorTotalJobs['Industry Sector'].values.tolist()
SectorGDPList = SectorGDP['Name'].values.tolist()

# %%
SectorGDPList
# Out:
# ['Gross domestic product',
#  'Private industries',
#  'Agriculture, forestry, fishing, and hunting',
#  'Mining',
#  'Utilities',
#  'Construction',
#  'Manufacturing',
#  'Durable goods',
#  'Nondurable goods',
#  'Wholesale trade',
#  'Retail trade',
#  'Transportation and warehousing',
#  'Information',
#  'Finance, insurance, real estate, rental, and leasing',
#  'Finance and insurance',
#  'Real estate and rental and leasing',
#  'Professional and business services',
#  'Professional, scientific, and technical services',
#  'Management of companies and enterprises',
#  'Administrative and waste management services',
#  'Educational services, health care, and social assistance',
#  'Educational services',
#  'Health care and social assistance',
#  'Arts, entertainment, recreation, accommodation, and food services',
#  'Arts, entertainment, and recreation',
#  'Accommodation and food services',
#  'Other services, except government',
#  'Government',
#  'Federal',
#  'State and local',
#  'Private goods-producing industries',
#  'Private services-producing industries']

# %%
SectorTotalJobsList
# Out:
# ['Mining',
#  'Construction',
#  'Manufacturing',
#  'Utilities',
#  'Wholesale trade',
#  'Retail trade',
#  'Transportation and warehousing',
#  'Information',
#  'Financial activities',
#  'Professional and business services',
#  'Educational services',
#  'Health care and social assistance',
#  'Leisure and hospitality',
#  'Other services',
#  'Federal government',
#  'State and local government',
#  'Agriculture, forestry, fishing, and hunting',
#  'Nonagriculture self-employed']

# %% [markdown]
# Find differences in lists

# %%
def findListDifference(list1, list2):
    difference = []
    for item in list1:
        if item not in list2:
            difference.append(item)
    return difference

# findListDifference(SectorTotalJobsList, SectorGDPList)
findListDifference(SectorGDPList, SectorTotalJobsList)
# Out:
# ['Gross domestic product',
#  'Private industries',
#  'Durable goods',
#  'Nondurable goods',
#  'Finance, insurance, real estate, rental, and leasing',
#  'Finance and insurance',
#  'Real estate and rental and leasing',
#  'Professional, scientific, and technical services',
#  'Management of companies and enterprises',
#  'Administrative and waste management services',
#  'Educational services, health care, and social assistance',
#  'Arts, entertainment, recreation, accommodation, and food services',
#  'Arts, entertainment, and recreation',
#  'Accommodation and food services',
#  'Other services, except government',
#  'Government',
#  'Federal',
#  'State and local',
#  'Private goods-producing industries',
#  'Private services-producing industries']

# %% [markdown]
# Modify differences
#
#  'Gross domestic product', - Delete
#  'Private industries', - Delete
#  'Durable goods', -> Retail trade
#  'Nondurable goods', -> Retail trade
#  'Finance, insurance, real estate, rental, and leasing', -> Financial activities
#  'Finance and insurance', -> Financial activities
#  'Real estate and rental and leasing', -> Construction
#  'Professional, scientific, and technical services', -> Professional and business services
#  'Management of companies and enterprises', -> Delete
#  'Administrative and waste management services', -> Delete
#  'Educational services, health care, and social assistance', -> Educational services
#  'Arts, entertainment, recreation, accommodation, and food services', - Leisure and hospitality
#  'Arts, entertainment, and recreation', - Leisure and hospitality

# %%
def renameCell(df, index, column, newValue):
    df.loc[index, column] = newValue
    return df

def renameRow(df, index, newName):
    df.loc[index] = newName
    return df

def removeRow(df, index):
    df.drop(index, inplace=True)
    return df

renameCell(SectorGDP, 7,  'Name', 'Retail trade')
renameCell(SectorGDP, 8,  'Name', 'Retail trade')
renameCell(SectorGDP, 13, 'Name',  'Financial activities')
renameCell(SectorGDP, 14, 'Name',  'Financial activities')
renameCell(SectorGDP, 15, 'Name',  'Construction')
renameCell(SectorGDP, 17, 'Name',  'Professional and business services')
renameCell(SectorGDP, 20, 'Name',  'Educational services')
renameCell(SectorGDP, 23, 'Name',  'Leisure and hospitality')
renameCell(SectorGDP, 24, 'Name',  'Leisure and hospitality')

removeRow(SectorGDP, 0)
removeRow(SectorGDP, 1)
removeRow(SectorGDP, 18)
removeRow(SectorGDP, 19)

SectorGDP
# Out:
#                                            Name  Q4 2021 (Billions of Dollars)
# 2   Agriculture, forestry, fishing, and hunting                          255.0
# 3                                        Mining                          336.1
# 4                                     Utilities                          401.6
# 5                                  Construction                          991.9
# 6                                 Manufacturing                         2714.2
# 7                                  Retail trade                         1440.0
# 8                                  Retail trade                         1274.2
# 9                               Wholesale trade                         1444.6
# 10                                 Retail trade                         1434.1
# 11               Transportation and warehousing                          698.0
# 12                                  Information                         1360.6
# 13                         Financial activities                         5024.7
# 14                         Financial activities                         2003.6
# 15                                 Construction                         3021.1
# 16           Professional and business services                         3109.1
# 17           Professional and business services                         1863.4
# 20                         Educational services                         1994.2
# 21                         Educational services                          266.8
# 22            Health care and social assistance                         1727.4
# 23                      Leisure and hospitality                          934.7
# 24                      Leisure and hospitality                          220.9
# 25              Accommodation and food services                          713.9
# 26            Other services, except government                          467.9
# 27                                   Government                         2836.2
# 28                                      Federal                          897.8
# 29                              State and local                         1938.4
# 30           Private goods-producing industries                         4297.1
# 31        Private services-producing industries                        16869.5

# %%
def groupBySum(df, column):
    df = df.groupby(column).sum()
    return df

SectorGDP = groupBySum(SectorGDP, 'Name')


# renameColumns(SectorGDP, ['Name', 'Industry Sector'])

SectorGDP
# Out:
#                                              Q4 2021 (Billions of Dollars)
# Name
# Accommodation and food services                                      713.9
# Agriculture, forestry, fishing, and hunting                          255.0
# Construction                                                        4013.0
# Educational services                                                2261.0
# Federal                                                              897.8
# Financial activities                                                7028.3
# Government                                                          2836.2
# Health care and social assistance                                   1727.4
# Information                                                         1360.6
# Leisure and hospitality                                             1155.6
# Manufacturing                                                       2714.2
# Mining                                                               336.1
# Other services, except government                                    467.9
# Private goods-producing industries                                  4297.1
# Private services-producing industries                              16869.5
# Professional and business services                                  4972.5
# Retail trade                                                        4148.3
# State and local                                                     1938.4
# Transportation and warehousing                                       698.0
# Utilities                                                            401.6
# Wholesale trade                                                     1444.6

# %%
# removeRow(SectorGDP, 0)

# %%
# def mergeData(df1, df2, column):
#     df1 = df1.merge(df2, on=column)
#     return df1

# mergeData(SectorGDP, SectorTotalJobs, 'Name')

# SectorTotalJobs

# %%
# SectorSectorGDP = SectorGDP.sort_values(by=['Q4 2021 (Billions of Dollars)'])

# def makePieChart(dataframe, column, title):
#     plt.figure(figsize=(8,8))
#     plt.title(title)
#     plt.pie(dataframe[column], labels=dataframe['Name'], autopct='%1.1f%%')
#     plt.axis('equal')
#     plt.show()

# print(makePieChart(SectorSectorGDP, 'Q4 2021 (Billions of Dollars)', 'Q4 2021 (Billions of Dollars)'))

# %%
JobsQualifications = openCSV('./JobsQualifications.csv')

def removeSpacesFromAllColumns(df):
    df.columns = df.columns.str.strip()
    return df

removeSpacesFromAllColumns(JobsQualifications)

JobsQualifications
# Out:
#                                             OCCUPATION  \
# 0                             Accountants and auditors
# 1                                               Actors
# 2                                            Actuaries
# 3    Acupuncturists and healthcare diagnosing or tr...
# 4       Adhesive bonding machine operators and tenders
# ..                                                 ...
# 785                             Woodworkers, all other
# 786  Woodworking machine setters, operators, and te...
# 787                        Word processors and typists
# 788                                Writers and authors
# 789                 Zoologists and wildlife biologists
#
#                  ENTRY-LEVEL EDUCATION                ON-THE-JOB TRAINING  \
# 0                    Bachelor’s degree                               None
# 1              Some college, no degree      Long-term on-the-job training
# 2                    Bachelor’s degree      Long-term on-the-job training
# 3                      Master’s degree                               None
# 4    High school diploma or equivalent  Moderate-term on-the-job training
# ..                                 ...                                ...
# 785  High school diploma or equivalent  Moderate-term on-the-job training
# 786  High school diploma or equivalent  Moderate-term on-the-job training
# 787  High school diploma or equivalent     Short-term on-the-job training
# 788                  Bachelor’s degree      Long-term on-the-job training
# 789                  Bachelor’s degree                               None
#
#     PROJECTED NUMBER OF NEW JOBS     PROJECTED GROWTH RATE  \
# 0                 50,000 or more        As fast as average
# 1               10,000 to 49,999  Much faster than average
# 2                 5,000 to 9,999  Much faster than average
# 3                 1,000 to 4,999       Slower than average
# 4                       0 to 999       Little or no change
# ..                           ...                       ...
# 785               1,000 to 4,999  Much faster than average
# 786               5,000 to 9,999        As fast as average
# 787                    Declining                   Decline
# 788             10,000 to 49,999        As fast as average
# 789               1,000 to 4,999       Slower than average
#
#                        2021 MEDIAN PAY
# 0                   $60,000 to $79,999
# 1    The annual wage is not available.
# 2                      $80,000 or more
# 3                      $80,000 or more
# 4                   $30,000 to $39,999
# ..                                 ...
# 785                 $30,000 to $39,999
# 786                 $30,000 to $39,999
# 787                 $40,000 to $59,999
# 788                 $60,000 to $79,999
# 789                 $60,000 to $79,999
#
# [790 rows x 6 columns]

# %%
JobsQualifications['ENTRY-LEVEL EDUCATION'].unique()
# Out:
# array(['Bachelor’s degree', 'Some college, no degree', 'Master’s degree',
#        'High school diploma or equivalent',
#        'Doctoral or professional degree', 'Associate’s degree',
#        'No formal educational credential',
#        'Postsecondary nondegree award'], dtype=object)

# %% [markdown]
# Bachelor’s degree', 'Some college, no degree', 'Master’s degree',
#        'High school diploma or equivalent',
#        'Doctoral or professional degree', 'Associate’s degree',
#        'No formal educational credential',
#        'Postsecondary nondegree award'], dtype=object)

# %%
JobsQualifications['2021 MEDIAN PAY'].unique()
# Out:
# array(['$60,000 to $79,999', 'The annual wage is not available.',
#        '$80,000 or more', '$30,000 to $39,999', '$40,000 to $59,999',
#        'Less than $30,000'], dtype=object)

# %%
def filterColumn(df, column, value):
    df = df[df[column] == value]
    return df

someCollege = filterColumn(JobsQualifications, 'ENTRY-LEVEL EDUCATION', 'Some college, no degree')
someCollegeLowWage  = filterColumn(someCollege, '2021 MEDIAN PAY', 'Less than $30,000')



highSchoolDiploma = filterColumn(JobsQualifications, 'ENTRY-LEVEL EDUCATION', 'High school diploma or equivalent')
highSchoolDiplomaLowWage  = filterColumn(highSchoolDiploma, '2021 MEDIAN PAY', 'Less than $30,000')

noFormalEducation = filterColumn(JobsQualifications, 'ENTRY-LEVEL EDUCATION', 'No formal educational credential')
noFormalEducationLowWage = filterColumn(noFormalEducation, '2021 MEDIAN PAY', 'Less than $30,000')

noFormalEducationLowWage['OCCUPATION'].unique()
# Out:
# array(['Amusement and recreation attendants',
#        'Automotive and watercraft service attendants', 'Bakers',
#        'Bartenders', 'Cashiers', 'Cleaners of vehicles and equipment',
#        'Cooks, fast food', 'Cooks, institution and cafeteria',
#        'Cooks, short order',
#        'Dining room and cafeteria attendants and bartender helpers',
#        'Dishwashers',
#        'Door-to-door sales workers, news and street vendors, and related workers',
#        'Farmworkers and laborers, crop, nursery, and greenhouse',
#        'Farmworkers, farm, ranch, and aquacultural animals',
#        'Fast food and counter workers',
#        'Food preparation and serving related workers, all other',
#        'Food preparation workers', 'Food servers, nonrestaurant',
#        'Gambling change persons and booth cashiers',
#        'Graders and sorters, agricultural products',
#        'Hosts and hostesses, restaurant, lounge, and coffee shop',
#        'Janitors and cleaners, except maids and housekeeping cleaners',
#        'Laundry and dry-cleaning workers',
#        'Lifeguards, ski patrol, and other recreational protective service workers',
#        'Maids and housekeeping cleaners',
#        'Meat, poultry, and fish cutters and trimmers',
#        'Motion picture projectionists', 'Packers and packagers, hand',
#        'Parking attendants',
#        'Pressers, textile, garment, and related materials',
#        'Retail salespersons', 'Sewers, hand', 'Sewing machine operators',
#        'Shampooers', 'Slaughterers and meat packers', 'Telemarketers',
#        'Ushers, lobby attendants, and ticket takers',
#        'Waiters and waitresses'], dtype=object)

# %%
SectorTotalJobs
# Out:
#                                 Industry Sector  Employment, 2010  \
# 0                                        Mining             654.8
# 1                                  Construction            5518.3
# 2                                 Manufacturing           11529.1
# 3                                     Utilities             552.8
# 4                               Wholesale trade            5386.6
# 5                                  Retail trade           14446.3
# 6                Transportation and warehousing            4179.2
# 7                                   Information            2707.2
# 8                          Financial activities            7694.8
# 9            Professional and business services           16782.9
# 10                         Educational services            3155.1
# 11            Health care and social assistance           16820.0
# 12                      Leisure and hospitality           13048.7
# 13                               Other services            5997.7
# 14                           Federal government            2977.0
# 15                   State and local government           19513.5
# 16  Agriculture, forestry, fishing, and hunting            2102.9
# 17                 Nonagriculture self-employed            8859.8
#
#     Employment, 2020  Employment, 2030  Employment change,   \
# 0              573.1             671.3                -81.7
# 1             7269.4            7584.4               1751.1
# 2            12179.1           12322.8                650.0
# 3              541.9             502.9                -10.9
# 4             5639.8            5780.8                253.2
# 5            14853.1           14266.3                406.8
# 6             5555.1            6189.2               1375.9
# 7             2694.4            2977.2                -12.8
# 8             8723.7            9027.1               1028.9
# 9            20245.7           22265.6               3462.8
# 10            3459.4            3983.6                304.3
# 11           19776.2           23092.6               2956.2
# 12           13326.7           16566.3                278.0
# 13            6048.8            6804.9                 51.1
# 14            2929.0            2860.9                -48.0
# 15           18979.8           19797.1               -533.7
# 16            2241.3            2296.3                138.4
# 17            8497.3            8424.3               -362.5
#
#     Employment change,  Percent distribution, 2010  \
# 0                 98.2                         0.5
# 1                315.0                         3.9
# 2                143.7                         8.1
# 3                -39.0                         0.4
# 4                141.0                         3.8
# 5               -586.8                        10.2
# 6                634.1                         2.9
# 7                282.8                         1.9
# 8                303.4                         5.4
# 9               2019.9                        11.8
# 10               524.2                         2.2
# 11              3316.4                        11.9
# 12              3239.6                         9.2
# 13               756.1                         4.2
# 14               -68.1                         2.1
# 15               817.3                        13.7
# 16                55.0                         1.5
# 17               -73.0                         6.2
#
#     Percent distribution, 2020  Percent distribution, 2030  \
# 0                          0.4                         0.4
# 1                          4.7                         4.6
# 2                          7.9                         7.4
# 3                          0.4                         0.3
# 4                          3.7                         3.5
# 5                          9.7                         8.6
# 6                          3.6                         3.7
# 7                          1.8                         1.8
# 8                          5.7                         5.5
# 9                         13.2                        13.5
# 10                         2.3                         2.4
# 11                        12.9                        14.0
# 12                         8.7                        10.0
# 13                         3.9                         4.1
# 14                         1.9                         1.7
# 15                        12.4                        12.0
# 16                         1.5                         1.4
# 17                         5.5                         5.1
#
#     Compound annual rate of change, 2010–20  \
# 0                                      -1.3
# 1                                       2.8
# 2                                       0.5
# 3                                      -0.2
# 4                                       0.5
# 5                                       0.3
# 6                                       2.9
# 7                                       0.0
# 8                                       1.3
# 9                                       1.9
# 10                                      0.9
# 11                                      1.6
# 12                                      0.2
# 13                                      0.1
# 14                                     -0.2
# 15                                     -0.3
# 16                                      0.6
# 17                                     -0.4
#
#     Compound annual rate of change, 2020–30
# 0                                       1.6
# 1                                       0.4
# 2                                       0.1
# 3                                      -0.7
# 4                                       0.2
# 5                                      -0.4
# 6                                       1.1
# 7                                       1.0
# 8                                       0.3
# 9                                       1.0
# 10                                      1.4
# 11                                      1.6
# 12                                      2.2
# 13                                      1.2
# 14                                     -0.2
# 15                                      0.4
# 16                                      0.2
# 17                                     -0.1

# %%
SectorTotalJobs = SectorTotalJobs.sort_values(by=['Employment, 2020'])


def makePieChart(dataframe, column, title):
    plt.figure(figsize=(8,8))
    plt.title(title)
    plt.pie(dataframe[column], labels=dataframe['Industry Sector'], autopct='%1.1f%%')
    plt.axis('equal')
    plt.show()

makePieChart(SectorTotalJobs, 'Employment, 2020', 'Industry Sector')

# %% [markdown]
# Professional

# %%
noFormalEducationLowWage
# Out:
#                                             OCCUPATION  \
# 27                 Amusement and recreation attendants
# 54        Automotive and watercraft service attendants
# 61                                              Bakers
# 63                                          Bartenders
# 99                                            Cashiers
# 116                 Cleaners of vehicles and equipment
# 157                                   Cooks, fast food
# 158                   Cooks, institution and cafeteria
# 161                                 Cooks, short order
# 203  Dining room and cafeteria attendants and barte...
# 205                                        Dishwashers
# 207  Door-to-door sales workers, news and street ve...
# 270  Farmworkers and laborers, crop, nursery, and g...
# 271  Farmworkers, farm, ranch, and aquacultural ani...
# 273                      Fast food and counter workers
# 310  Food preparation and serving related workers, ...
# 311                           Food preparation workers
# 314                        Food servers, nonrestaurant
# 332         Gambling change persons and booth cashiers
# 347         Graders and sorters, agricultural products
# 380  Hosts and hostesses, restaurant, lounge, and c...
# 406  Janitors and cleaners, except maids and housek...
# 416                   Laundry and dry-cleaning workers
# 430  Lifeguards, ski patrol, and other recreational...
# 447                    Maids and housekeeping cleaners
# 465       Meat, poultry, and fish cutters and trimmers
# 503                      Motion picture projectionists
# 548                        Packers and packagers, hand
# 554                                 Parking attendants
# 606  Pressers, textile, garment, and related materials
# 655                                Retail salespersons
# 683                                       Sewers, hand
# 684                           Sewing machine operators
# 685                                         Shampooers
# 693                      Slaughterers and meat packers
# 740                                      Telemarketers
# 772        Ushers, lobby attendants, and ticket takers
# 776                             Waiters and waitresses
#
#                 ENTRY-LEVEL EDUCATION                ON-THE-JOB TRAINING  \
# 27   No formal educational credential     Short-term on-the-job training
# 54   No formal educational credential     Short-term on-the-job training
# 61   No formal educational credential      Long-term on-the-job training
# 63   No formal educational credential     Short-term on-the-job training
# 99   No formal educational credential     Short-term on-the-job training
# 116  No formal educational credential     Short-term on-the-job training
# 157  No formal educational credential     Short-term on-the-job training
# 158  No formal educational credential     Short-term on-the-job training
# 161  No formal educational credential     Short-term on-the-job training
# 203  No formal educational credential     Short-term on-the-job training
# 205  No formal educational credential     Short-term on-the-job training
# 207  No formal educational credential     Short-term on-the-job training
# 270  No formal educational credential     Short-term on-the-job training
# 271  No formal educational credential     Short-term on-the-job training
# 273  No formal educational credential     Short-term on-the-job training
# 310  No formal educational credential     Short-term on-the-job training
# 311  No formal educational credential     Short-term on-the-job training
# 314  No formal educational credential     Short-term on-the-job training
# 332  No formal educational credential     Short-term on-the-job training
# 347  No formal educational credential     Short-term on-the-job training
# 380  No formal educational credential     Short-term on-the-job training
# 406  No formal educational credential     Short-term on-the-job training
# 416  No formal educational credential     Short-term on-the-job training
# 430  No formal educational credential     Short-term on-the-job training
# 447  No formal educational credential     Short-term on-the-job training
# 465  No formal educational credential     Short-term on-the-job training
# 503  No formal educational credential     Short-term on-the-job training
# 548  No formal educational credential     Short-term on-the-job training
# 554  No formal educational credential     Short-term on-the-job training
# 606  No formal educational credential     Short-term on-the-job training
# 655  No formal educational credential     Short-term on-the-job training
# 683  No formal educational credential  Moderate-term on-the-job training
# 684  No formal educational credential     Short-term on-the-job training
# 685  No formal educational credential     Short-term on-the-job training
# 693  No formal educational credential     Short-term on-the-job training
# 740  No formal educational credential     Short-term on-the-job training
# 772  No formal educational credential     Short-term on-the-job training
# 776  No formal educational credential     Short-term on-the-job training
#
#     PROJECTED NUMBER OF NEW JOBS     PROJECTED GROWTH RATE    2021 MEDIAN PAY
# 27                50,000 or more  Much faster than average  Less than $30,000
# 54                5,000 to 9,999       Slower than average  Less than $30,000
# 61              10,000 to 49,999        As fast as average  Less than $30,000
# 63                50,000 or more  Much faster than average  Less than $30,000
# 99                     Declining                   Decline  Less than $30,000
# 116             10,000 to 49,999        As fast as average  Less than $30,000
# 157                    Declining                   Decline  Less than $30,000
# 158             10,000 to 49,999        As fast as average  Less than $30,000
# 161             10,000 to 49,999        As fast as average  Less than $30,000
# 203               50,000 or more  Much faster than average  Less than $30,000
# 205               50,000 or more  Much faster than average  Less than $30,000
# 207                    Declining                   Decline  Less than $30,000
# 270             10,000 to 49,999       Slower than average  Less than $30,000
# 271                    Declining                   Decline  Less than $30,000
# 273               50,000 or more       Faster than average  Less than $30,000
# 310             10,000 to 49,999  Much faster than average  Less than $30,000
# 311               50,000 or more        As fast as average  Less than $30,000
# 314             10,000 to 49,999       Faster than average  Less than $30,000
# 332               1,000 to 4,999  Much faster than average  Less than $30,000
# 347                    Declining       Little or no change  Less than $30,000
# 380               50,000 or more  Much faster than average  Less than $30,000
# 406               50,000 or more        As fast as average  Less than $30,000
# 416             10,000 to 49,999       Faster than average  Less than $30,000
# 430             10,000 to 49,999  Much faster than average  Less than $30,000
# 447               50,000 or more       Faster than average  Less than $30,000
# 465               5,000 to 9,999       Slower than average  Less than $30,000
# 503               1,000 to 4,999  Much faster than average  Less than $30,000
# 548               1,000 to 4,999       Little or no change  Less than $30,000
# 554             10,000 to 49,999       Faster than average  Less than $30,000
# 606                    Declining                   Decline  Less than $30,000
# 655                    Declining       Little or no change  Less than $30,000
# 683                    Declining                   Decline  Less than $30,000
# 684                    Declining                   Decline  Less than $30,000
# 685               1,000 to 4,999  Much faster than average  Less than $30,000
# 693               1,000 to 4,999       Slower than average  Less than $30,000
# 740                    Declining                   Decline  Less than $30,000
# 772               50,000 or more  Much faster than average  Less than $30,000
# 776               50,000 or more  Much faster than average  Less than $30,000

# %%
def splitWordsBySpace(list):
    newList = []
    for word in list:
        newList.append(word.split(' '))
    return newList

def makeListOfWordsFromColumn(df, column):
    list = []
    for words in df[column]:
        words = words.split(' ')
        for word in words:
            list.append(word)
    return list

occupationList = makeListOfWordsFromColumn(noFormalEducationLowWage, 'OCCUPATION')

occupationList
# Out:
# ['Amusement',
#  'and',
#  'recreation',
#  'attendants',
#  'Automotive',
#  'and',
#  'watercraft',
#  'service',
#  'attendants',
#  'Bakers',
#  'Bartenders',
#  'Cashiers',
#  'Cleaners',
#  'of',
#  'vehicles',
#  'and',
#  'equipment',
#  'Cooks,',
#  'fast',
#  'food',
#  'Cooks,',
#  'institution',
#  'and',
#  'cafeteria',
#  'Cooks,',
#  'short',
#  'order',
#  'Dining',
#  'room',
#  'and',
#  'cafeteria',
#  'attendants',
#  'and',
#  'bartender',
#  'helpers',
#  'Dishwashers',
#  'Door-to-door',
#  'sales',
#  'workers,',
#  'news',
#  'and',
#  'street',
#  'vendors,',
#  'and',
#  'related',
#  'workers',
#  'Farmworkers',
#  'and',
#  'laborers,',
#  'crop,',
#  'nursery,',
#  'and',
#  'greenhouse',
#  'Farmworkers,',
#  'farm,',
#  'ranch,',
#  'and',
#  'aquacultural',
#  'animals',
#  'Fast',
#  'food',
#  'and',
#  'counter',
#  'workers',
#  'Food',
#  'preparation',
#  'and',
#  'serving',
#  'related',
#  'workers,',
#  'all',
#  'other',
#  'Food',
#  'preparation',
#  'workers',
#  'Food',
#  'servers,',
#  'nonrestaurant',
#  'Gambling',
#  'change',
#  'persons',
#  'and',
#  'booth',
#  'cashiers',
#  'Graders',
#  'and',
#  'sorters,',
#  'agricultural',
#  'products',
#  'Hosts',
#  'and',
#  'hostesses,',
#  'restaurant,',
#  'lounge,',
#  'and',
#  'coffee',
#  'shop',
#  'Janitors',
#  'and',
#  'cleaners,',
#  'except',
#  'maids',
#  'and',
#  'housekeeping',
#  'cleaners',
#  'Laundry',
#  'and',
#  'dry-cleaning',
#  'workers',
#  'Lifeguards,',
#  'ski',
#  'patrol,',
#  'and',
#  'other',
#  'recreational',
#  'protective',
#  'service',
#  'workers',
#  'Maids',
#  'and',
#  'housekeeping',
#  'cleaners',
#  'Meat,',
#  'poultry,',
#  'and',
#  'fish',
#  'cutters',
#  'and',
#  'trimmers',
#  'Motion',
#  'picture',
#  'projectionists',
#  'Packers',
#  'and',
#  'packagers,',
#  'hand',
#  'Parking',
#  'attendants',
#  'Pressers,',
#  'textile,',
#  'garment,',
#  'and',
#  'related',
#  'materials',
#  'Retail',
#  'salespersons',
#  'Sewers,',
#  'hand',
#  'Sewing',
#  'machine',
#  'operators',
#  'Shampooers',
#  'Slaughterers',
#  'and',
#  'meat',
#  'packers',
#  'Telemarketers',
#  'Ushers,',
#  'lobby',
#  'attendants,',
#  'and',
#  'ticket',
#  'takers',
#  'Waiters',
#  'and',
#  'waitresses']

# %%
# def findWordFrequency(dataframe, column):
#     from collections import Counter
#     word_count = Counter(dataframe[column])
#     return word_count

# findWordFrequency(noFormalEducationLowWage, 'OCCUPATION')

# %%
# %pip install wordcloud
from wordcloud import WordCloud 

def makeWordCloud(list, title):
    wordcloud = WordCloud(width=800, height=800, max_font_size=200).generate(' '.join(list))
    plt.figure(figsize=(10,10))
    plt.title(title)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.show()

makeWordCloud(occupationList, 'Lowest wage occupations & least qualified occupations')
# Out:
# Requirement already satisfied: wordcloud in /opt/homebrew/anaconda3/lib/python3.9/site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: pillow in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: six in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def removeWordsFromList(list, censoredWords):
    tmpList = []
    for word in list:
        if word in censoredWords:
            continue
        else:
            tmpList.append(word)
    return tmpList

cleanedOccupationList =  removeWordsFromList(occupationList, ['and', 'of', 'other', 'food','related'])
cleanedOccupationList
# Out:
# ['Amusement',
#  'recreation',
#  'attendants',
#  'Automotive',
#  'watercraft',
#  'service',
#  'attendants',
#  'Bakers',
#  'Bartenders',
#  'Cashiers',
#  'Cleaners',
#  'vehicles',
#  'equipment',
#  'Cooks,',
#  'fast',
#  'Cooks,',
#  'institution',
#  'cafeteria',
#  'Cooks,',
#  'short',
#  'order',
#  'Dining',
#  'room',
#  'cafeteria',
#  'attendants',
#  'bartender',
#  'helpers',
#  'Dishwashers',
#  'Door-to-door',
#  'sales',
#  'workers,',
#  'news',
#  'street',
#  'vendors,',
#  'workers',
#  'Farmworkers',
#  'laborers,',
#  'crop,',
#  'nursery,',
#  'greenhouse',
#  'Farmworkers,',
#  'farm,',
#  'ranch,',
#  'aquacultural',
#  'animals',
#  'Fast',
#  'counter',
#  'workers',
#  'Food',
#  'preparation',
#  'serving',
#  'workers,',
#  'all',
#  'Food',
#  'preparation',
#  'workers',
#  'Food',
#  'servers,',
#  'nonrestaurant',
#  'Gambling',
#  'change',
#  'persons',
#  'booth',
#  'cashiers',
#  'Graders',
#  'sorters,',
#  'agricultural',
#  'products',
#  'Hosts',
#  'hostesses,',
#  'restaurant,',
#  'lounge,',
#  'coffee',
#  'shop',
#  'Janitors',
#  'cleaners,',
#  'except',
#  'maids',
#  'housekeeping',
#  'cleaners',
#  'Laundry',
#  'dry-cleaning',
#  'workers',
#  'Lifeguards,',
#  'ski',
#  'patrol,',
#  'recreational',
#  'protective',
#  'service',
#  'workers',
#  'Maids',
#  'housekeeping',
#  'cleaners',
#  'Meat,',
#  'poultry,',
#  'fish',
#  'cutters',
#  'trimmers',
#  'Motion',
#  'picture',
#  'projectionists',
#  'Packers',
#  'packagers,',
#  'hand',
#  'Parking',
#  'attendants',
#  'Pressers,',
#  'textile,',
#  'garment,',
#  'materials',
#  'Retail',
#  'salespersons',
#  'Sewers,',
#  'hand',
#  'Sewing',
#  'machine',
#  'operators',
#  'Shampooers',
#  'Slaughterers',
#  'meat',
#  'packers',
#  'Telemarketers',
#  'Ushers,',
#  'lobby',
#  'attendants,',
#  'ticket',
#  'takers',
#  'Waiters',
#  'waitresses']

# %%
def frequencyDistributionFromList(list):
    from collections import Counter
    word_count = Counter(list)
    return word_count

frequencyDistributionCounter = frequencyDistributionFromList(cleanedOccupationList).most_common(20)

# frequencyDistributionCounter
# def sortCounter(counter):
#     return counter.most_common()

# sortedFrequencyDistribution = sortCounter(frequencyDistributionCounter)
# sortedFrequencyDistribution

def tupleToDictionary(tuple):
    dictionary = {}
    for key, value in tuple:
        dictionary[key] = value
    return dictionary

frequencyDistributionCounter = tupleToDictionary(frequencyDistributionCounter)
frequencyDistributionCounter
# Out:
# {'workers': 5,
#  'attendants': 4,
#  'Cooks,': 3,
#  'Food': 3,
#  'service': 2,
#  'cafeteria': 2,
#  'workers,': 2,
#  'preparation': 2,
#  'housekeeping': 2,
#  'cleaners': 2,
#  'hand': 2,
#  'Amusement': 1,
#  'recreation': 1,
#  'Automotive': 1,
#  'watercraft': 1,
#  'Bakers': 1,
#  'Bartenders': 1,
#  'Cashiers': 1,
#  'Cleaners': 1,
#  'vehicles': 1}

# %%
def makeFrequencyDistributionChart(list, title):
    plt.figure(figsize=(10,10))
    plt.title(title)
    plt.bar(list.keys(), list.values())
    plt.xticks(rotation=90)
    plt.show()

makeFrequencyDistributionChart(frequencyDistributionCounter, 'Frequency distribution of occupations')
